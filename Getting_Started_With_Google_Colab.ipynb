# %% [markdown]
# <a href="https://colab.research.google.com/github/krmonline/Sentiment-Analysis-in-Social-Networks/blob/master/Getting_Started_With_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/"
# Out:
# ' สัมภาษณ์งาน'
#  อ.เอก
#  แม่
#  สตส
#  ปปช
#  หุ้น
#  บ้าน
#  เอ็ด
#  เขาใหญ่
#  ศิริราช
# 'สำนักงาน ปปช'
#  อาจารย์เอก
#  00001.vcf
#  001_ch7_wi_2017.html
# 'แผนงบประมาณเดือน ก.ค. 14.xlsx'
# '1.7.การเงิน ก.ค. 14.xls'
# '1.7.P&L ก.ค. 14.xls'
#  1c247c7.jpg
# 'แบบแผนที่ยังไม่ได้ตั้งชื่อ (1).html'
#  เค้าโครง+..1.ppt
#  เค้าโครง+..1.ppt.gslides
# '_________ __________ (1).xls'
# '_________ __________ (1).xls.gsheet'
# 'งบค่าใช้จ่าย (1).xlsx.gsheet'
# '20130523-nat and logging comply.gsheet'
#  20131227_101331.jpg
#  2016
#  20170105090642.pdf
# 'ภาษี 2019'
# '20530_พนักงานเลือกการลงทุนเอง (1).doc'
#  20530_พนักงานเลือกการลงทุนเอง.doc
#  20530_พนักงานเลือกการลงทุนเอง.doc.gdoc
#  20.png
#  21.gsheet
# 'แบบคำนวนเงินเดือน. 2557xls_.gsheet'
# '???? ????????? 2559 (???.?????).xlsx'
#  26_issue2017.pptx.gslides
#  27229EE3-10F5-49F4-B3C6-6F989830760A.jpeg
# 'สรุปประชุม 280159.docx'
# 'สรุปประชุม 280159.docx.gdoc'
# 'สรุปการลา%2Bเงินเดือน%2Bค่าคอม ทั้งปี... (2).xlsx'
# 'สรุปการลา%2Bเงินเดือน%2Bค่าคอม ทั้งปี... (2).xlsx.gsheet'
# 'สรุปการลา+เงินเดือน+ค่าคอม ทั้งปี... (2).gsheet'
#  หุ้น2.gsheet
# 'แบบแผนที่ยังไม่ได้ตั้งชื่อ (2).html'
# '2-mongodbfundamentals-121026111945-phpapp02 (1).gslides'
# '_________ __________ (2).xls.gsheet'
#  3bbcalculator.ods.gsheet
#  3BB-CGN-Log-server-farm.pdf
# '3bb information_average_size.gsheet'
# '3BB Information.gsheet'
#  3BB-NAT444-POC_Result_R1.pptx
# '3BB POC Update 07052014.gslides'
#  3BB-Softnix-Questions-Answers.gsheet
# '3BB Training Day 2'
# 'แบบแผนที่ยังไม่ได้ตั้งชื่อ (3).html'
# '_________ __________ (3).xls.gsheet'
#  4.2.2.3.5.gdoc
#  4.2.2.3.5.gsheet
#  49.230.207.11.csv
#  49.230.207.11.csv.gsheet
# 'แบบแผนที่ยังไม่ได้ตั้งชื่อ (4).html'
# '_________ __________ (4).xls.gsheet'
# 'ลงยอดแก้ไข ประมาณการ (ภงด.51) ปี 2557.xlsx.gsheet'
#  ผู้บาดเจ็บและเสียชีวิต_ในช่วงเทศกาล_ปี_51-58_CutName_NewYear_Edit.xlsx
# 'แผนงบประมาณปี 57 (1).xlsx.gsheet'
#  5728d9c4fbcb5f0ae4802620.xlsx
# 'สรุปใบลาปี 57.xlsx'
# 'แผนงบประมาณปี 57.xlsx'
# 'สรุปใบลาปี 57.xlsx.gsheet'
# 'แผนงบประมาณปี 57.xlsx.gsheet'
# 'กฎระเบียบของบริษัท ปี59.PDF'
# '5 element.gsheet'
# 'ประมาณการณ์ ภาษีงบปี 60-1.xlsx'
#  6_benchmarks.333.1472894038.pdf
#  8D0EDD13-4FB3-4FE3-9E7C-A6A198AE3F04.jpeg
# 'แผนงบประมาณเดือน 8.xlsx'
# 'แผนงบประมาณเดือน 8.xlsx.gsheet'
# 'a10_tls (1).gsheet'
#  a10_tls.gsheet
#  a10tls.gsheet
#  aacp-quota-mgr.gdoc
#  aacp-quota-mgr-schedule.gsheet
# 'Acceptance Test Procedure_v1.2_20140212.doc.gdoc'
#  action_Plan_update_menu_wifi_docsis.xlsx
#  action_Plan_update_menu_wifi_docsis.xlsx.gsheet
# 'active license.gdoc'
# 'สรุป Activity วันที่ 15 12 2016.gsheet'
# 'Activity 20 01 2017.gslides'
#  adB432.pdf
#  Administration_Training_1days.gslides
# 'Administration_Training_CPALL (1).pptx.gslides'
#  Administration_Training_CPALL.pptx
#  Administration_Training_CPALL.pptx.gslides
# 'Administration_Training_Installation_Zabbix_CPALL-update (1).pptx.gslides'
#  Administration_Training_Installation_Zabbix_CPALL-update.pptx
#  Administration_Training_Installation_Zabbix_CPALL-update.pptx.gslides
# 'ADSL MonitoringDATA.gsheet'
# 'คำนวณภาษี Ae.gsheet'
# 'ae_sawmill presentation.gslides'
#  ae_statement.txt.gdoc
#  ae_statement.xls.gsheet
#  agile
# 'Agile Presentation.gslides'
#  AI_chapter04b.pdf
#  ais
#  ais3
# 'AIS3 prototype temp.gslides'
#  AIS3.vsd
# 'AIS 4G cut traffic to CGN SILA_20160526.pdf'
#  ais_7d_cwdc.csv
#  ais_7d_cwdc.gsheet
# 'AIS CGN Action Plan_change cpu core Log collector_0.2.xlsx.gsheet'
# 'AIS CGN Action Plan_change cpu core Log collector_ae_0.1.xls.gsheet'
# 'AIS CGN Action Plan_change cpu core Log collector_ae_0.1.xls.xlsx'
# 'AIS CGN Action Plan_change cpu core Log collector.xls'
# 'AIS CGN Action Plan_change_cpu_ore_TLS.xlsx.gsheet'
# 'AIS CGN Action Plan_change dash to zero and timeformat v1.xlsx.gsheet'
# 'AIS CGN Action Plan_change IPV4 IPV6 and domain v1.xlsx.gsheet'
# 'AIS CGN Action Plan_change Perl script and change core  cpu 28032016.xlsx'
# 'AIS CGN Action Plan_change Perl script and change core  cpu 28032016.xlsx.gsheet'
# 'AIS CGN Action Plan_change Perl script and change core cpu 30032016.xlsx'
# 'AIS CGN Action Plan_change Perl script.xlsx.gsheet'
# 'AIS CGN action plan_cut_log_to_new_2_collector.gsheet'
# 'AIS CGN action plan_cut_log_to_new_2_collector_v3.xlsx'
# 'AIS CGN Action Plan_Move Log collector.xls'
# 'AIS CGN Action Plan_move_physical.gsheet'
#  AIS-CGN_CFMS_Alarm_V.1.0.0.xlsx.gsheet
#  AIS-CGN-Performance.gslides
#  ais_cgn_tmp
#  ais_coperate_log_diagram
#  ais_copperatelog
# 'AIS Copperate_V1.0 .gdoc'
#  AISCopperate_V1.0.gdoc
# 'AIS eps week summary.gsheet'
# 'AIS - Fix issue 16112015.gslides'
#  ais_hcgn
#  AIS_HCGN_DesignSpecification_V1.0.1.docx
# 'AIS_HCGN_DesignSpecification_V1.0.1.docx (1).docx.gdoc'
#  AIS_HCGN_DesignSpecification_V1.0.1.docx.gdoc
#  AIS_HCGN_SystemArhitecture_V.1.0.0.docx
#  AIS_HCGN_SystemArhitecture_V.1.0.0.docx.gdoc
# 'AIS_HCGN_UAT_Part1_V.0.2.1 (1).docx'
# 'AIS_HCGN_UAT_Part1_V.0.2.1 (1).docx.gdoc'
# 'AIS_HCGN_UAT_Part1_V.0.2.1 (2).docx'
# 'AIS_HCGN_UAT_Part1_V.0.2.1 (2).docx.gdoc'
# 'AIS_HCGN_UAT_Part1_V.0.2.1 (3).docx.gdoc'
#  AIS_HCGN_UAT_Part1_V.0.2.1.docx
#  AIS_HCGN_UAT_Part1_V.0.2.1.docx.gdoc
#  AIS_HCGN_UAT_Part2_V.0.2.0.docx
#  AIS_HCGN_UAT_Part2_V.0.2.0.docx.gdoc
#  AIS_HCGN_UAT_V.0.0.1.gdoc
#  AIS_information_report_28052014.gdoc
# ' AIS Monthly Report 092014.gslides'
# 'AIS Monthly Report 102014.gslides'
# 'AIS Monthly Report 122014.gslides'
# 'AIS Monthly Report.gslides'
# 'AIS Monthly Report Jan-Mar 2015.gslides'
# 'AIS Monthly Report Sep 2015.gslides'
# 'AIS OJT.gslides'
#  ais_poc_size_09092014.csv
#  ais_poc_size_09092014.csv.gdoc
#  ais_poc_size_09092014.gsheet
# 'ais port usage.gsheet'
# 'AIS Report 3 Site.pptx'
# 'AIS Report 3 Site.pptx.gslides'
# 'Ais Screen short & Prototype .gslides'
# 'Ais Screen short & Prototype .pptx'
# 'Ais Screen short & Prototype .pptx.gslides'
#  ais_sila
#  AIS_Software_API_Version_1.1.gdoc
#  ais_tmp
#  alarmlist_and_format.xls
#  alarmlist_and_format.xls.gsheet
#  algorithm
# 'Annual budget.gsheet'
# 'Anomaly Detection Process.drawio'
#  a.odp
#  APR-ALL-2014.gsheet
#  ArchitectureDesignForCybertron.html
# 'Architecture v1.pptx'
# 'Assignment-Workload Characterization.xlsx'
# 'Assignment-Workload Characterization.xlsx.xlsx'
#  audit_062015
# 'Availability Report User Acceptance Test CP-ALL-rev-1 (1).docx.gdoc'
# 'Availability Report User Acceptance Test CP-ALL-rev-1 (2).docx.gdoc'
# 'Availability Report User Acceptance Test CP-ALL-rev-1.docx'
# 'Availability Report User Acceptance Test CP-ALL-rev-1.docx.gdoc'
# 'Awesome Note'
#  backup_20140809_011504.abf
# 'สรุป การทดสอบ Backup DB by Percona Xtrabackup (1).docx'
# 'สรุป การทดสอบ Backup DB by Percona Xtrabackup (1).docx.gdoc'
# 'สรุป การทดสอบ Backup DB by Percona Xtrabackup.docx'
# 'สรุป การทดสอบ Backup DB by Percona Xtrabackup.docx.gdoc'
#  baiorn
# 'Basic Work Profile Part 2 - AE.gdoc'
#  bazi
# 'bb cgn mtg syslog parameter version a.0 (1).gsheet'
# 'bb cgn mtg syslog parameter version a.0 (2).gsheet'
# 'bb cgn mtg syslog parameter version a.0.gsheet'
# 'bb cgn ttw syslog parameter version 1.0.gsheet'
# 'BB CGN TTW Syslog Parameter Version 1.0.xlsx'
#  big-data-analytics-emrg-arch.epub
#  big-data-analytics-emrg-arch.pdf
# 'Bigdata log query solution.gslides'
# "Big Data Now: Current Perspectives from O'Reilly Radar.mobi"
#  bigdata_tools
#  BilledStatement_25102017_09149331.pdf
#  binarysearch.gsheet
#  bmta
#  bonus2014.gsheet
#  Bonus.gsheet
#  book1.gsheet
# 'Boonthavorn migrate SMS .gsheet'
#  bpsiiw.gmap
#  bsru_ip_assignment_rev2.xlsx.gsheet
# 'Business flow.pptx'
# 'Business flow.pptx.gslides'
# 'c2 (1).gsheet'
#  c2.csv
#  c2.gsheet
# 'c3 (1).csv'
#  c3.csv
#  c3.gsheet
# 'Car care.gsheet'
# 'Car care.xlsx.gsheet'
# 'Case study.gslides'
#  cc.xlsx
#  certificate
# 'CGN Add node.gsheet'
#  CGNlog_assignment_20150612.gsheet
#  CGNlog_assignment_20150618.gsheet
#  CGNlog_assignment_20160422.xlsx
#  CGNlog_assignment_20160422.xlsx.gsheet
#  CGN_log_project_progress_201508051900.gslides
# "CH12xx Install Corrector 'Cisco_ASA_Event_Collector_4.4.11' on SSIM.XLS"
#  ch7_09012017.gslides
# 'ch7 20 jan 2017.gslides'
# 'Ch7 mom 22 dec 2016.gslides'
# 'CH7 SLG Change 03022017 .gslides'
#  ch7_summary_report.pptx.gslides
# 'Chakrit 2.pdf'
# 'Chakrit Profiles.gslides'
# 'แสดงกระบวนการของการทำ Change Request.doc'
#  CheckListNewInstalleMailServer.pdf
#  CheckListNewInstalleMailServer.pdf.gdoc
# 'Checklist-RFP-SW (1).gsheet'
#  Checklist-RFP-SW.gsheet
# 'Check List Softnix Logger 032014.gsheet'
# 'Check List Softnix Logger 052014.gsheet'
# ' Check List Softnix Logger062014.gsheet'
# 'Check List Softnix Logger062014.gsheet'
# 'check list softnix logger (1).gsheet'
# 'check list softnix logger.gsheet'
# 'Check List Softnix Logger NSTDA 022015.gsheet'
# 'Check List Softnix Logger NSTDA 042014.gsheet'
# 'Check List Softnix Logger.xls'
# 'Check List Softnix Logger.xlsx'
#  chula
# 'Chula_slg_diagram Active-Active.html'
# 'Chula_slg_diagram Active-Standby.html'
#  Chula_syslog_solutions.gslides
#  Classroom
# 'Class syslog-ng structure.gsheet'
#  CL_HADOOP_AIS.pdf
# 'Cloudera Hadoop Admin course.zip'
# 'Cloudera SNMP Alert format.gslides'
# 'Cloud Print test page.pdf'
#  Cluster-Doc.odt
#  Cmmi
#  co042012_report2.gsheet
#  co042014.gsheet
#  colab
#  colab_data
# 'Colab Notebooks'
# 'collector 11 ip.gsheet'
# 'การคำนวนจำนวน collector สำหรับ ais phase 3.gsheet'
# 'collector summary.gslides'
# 'Commission_July 16.xlsx'
# 'Commission_June 16.xlsx'
# 'Commission_June 16.xlsx.gsheet'
# 'compare log size by collector2014-07-24 and 2014-06-12.xlsx.gsheet'
# 'compress ratio gz bz2 lz4.gdoc'
# 'compress ratio gz bz2 lz4.gsheet'
# 'Compress ratio gz bz2 lz4.gsheet'
# 'Compress ratio gz bz2 lz4.xlsx'
# 'Com Sale_SO580511068 Processor Group_กรมโยธา (SLG-SA1 500GB).gsheet'
# 'ComService_SO581127190 Zabbix Major.xls Training.xls'
# 'ComService_SO581127190 Zabbix Major.xls Training.xls.gsheet'
# 'Com_SO580728122 SLG_2TB_Yipinsoi_กรมเจ้าท่า.gsheet'
# 'Com_SO580728122 SLG_2TB_Yipinsoi_กรมเจ้าท่า.xls.gsheet'
# 'Com_SO581202193 SLG_Pplus_phase3.xls'
# 'Com_SO590118015 SW-Zabbix_Gosoft.xls'
# 'Com_SO590118015 SW-Zabbix_Gosoft.xls.gsheet'
# 'Com_SO590401053 SLG-SA2_Ampo_ONEP.xls'
# 'Com_SO590401053 SLG-SA2_Ampo_ONEP.xls.gsheet'
# 'Com_SO590422062 MA-DNS Inet.xls'
# 'Com_SO590422062 MA-DNS Inet.xls.gsheet'
# 'Com_SO590513071 SLG-SW-1.5TB_STelligence _PSP.xls'
# 'Com_SO590513071 SLG-SW-1.5TB_STelligence _PSP.xls.gsheet'
# 'การสำเนา config ของ Softnix Logger.gsheet'
# 'การ config syslog กับอุปกรณืต่างๆ.gdoc'
# 'Configuration & Administration Guide.gdoc'
# 'Configuration & Operation Guide Report.docx'
# 'Configuration & Operation Guide Report.docx.gdoc'
# 'Confirmation letter.pdf'
# 'Confirm_User&pass.xlsx'
# 'Confirm_User&pass.xlsx.gsheet'
# 'Consulting proposal (1).gslides'
# 'Consulting proposal.gslides'
# 'Consult Plan (1).docx.gdoc'
#  CONTRIBUTING.md.gdoc
# 'Coperate AIS  Time Line V1.3.gsheet'
# 'Copy of สรุปการลา%2Bเงินเดือน%2Bค่าคอม ทั้งปี....gsheet'
# 'Copy of 5770995021.docx'
# 'Copy of Bowling Score Calculator.gsheet'
# 'Copy of Bug-List2010-07-06-2010.gsheet'
# 'Copy of Change Request Impact Assessment.gdoc'
# 'Copy of Copy of หุ้น.gsheet'
# 'Copy of FATC_Rev2_update_by_softnix_03062014.doc.gdoc'
# 'Copy of Grokking_Algorithms.pdf'
# 'Copy of หุ้น.gsheet'
# 'Copy of สรุปการลา+เงินเดือน+ค่าคอม ทั้งปี...เอ๋(ต้นฉบับ).gsheet'
# 'Copy of icsse.v1.pptx.gslides'
# 'Copy of Linear Neuron.gsheet'
# 'Copy of PageRank.gsheet'
# 'Copy of Presentation - Professional (Cool).gslides'
# 'Copy of ProjectCharterPOCSoftnixloggerhadoopPPlus.docx'
# 'Copy of PyTorch Lab 2 - XOR.ipynb'
# 'Copy of Requirements Traceability Matrix Template.gsheet'
# 'Copy of Sawmill Administrator Training.pptx.gslides'
# 'Copy of SLG_Trainig_SLG6.3-RealMove_ae_backup.gslides'
# 'Copy of Softnix PHP exam.gdoc'
# 'Copy of Software_Development_using_ISO 29110_rev0.ppt.gslides'
# 'Copy of SRT-DataGov-ปิดโครงการ Rev_01.pdf'
# 'Copy of Statement of Work.gdoc'
# 'Copy of summary28-01-2013.gsheet'
# 'Copy of Template za HL (zeleno+portokalovo).gslides'
# 'Copy of Test Case Template.gsheet'
# 'Copy of _________ __________.xls'
# 'Copy of zabbix_issue5.pptx.gslides'
#  cor1.gdoc
# 'Cosine  Sim.drawio'
#  cost_com
#  Course_Outline__Softnix_Logger_collector_ais14062016.gdoc
#  Course_Outline__Softnix_Logger_ISP_6hr.doc
#  Course_Outline__Softnix_Logger_ISP_6hr.gdoc
#  cover2.jpg
#  covidRiskPlace.gsheet
#  cpall24shop.gsheet
# 'CPAll Feature .xlsx.gsheet'
#  CPall.gslides
# 'cpall performance tuning10032016.gsheet'
# 'ใบส่งมอบงาน CPALL PHASE2.gdoc'
# 'CPALL Purge Data Metting 21 08 2015.gslides'
# 'CPALL Storage Optimize 15062015.gsheet'
# 'CPALL Storage Optimize 15062015.xlsx.gdoc'
# 'CPALL Storage Optimize & Backup Near Realtime 30062015.xlsx'
# 'CPALL Ticket support 29042015.gsheet'
# 'CPALL zabbix problem.gdoc'
# 'credit 072018.gsheet'
#  Credit2.gsheet
# 'crontab Softnix Logger 6.0.5.gsheet'
# 'Customer Profitability.xlsx'
#  customers
# 'cut ls.gslides'
# 'ผลการ cut traffic sila 02062016.gslides'
# 'ผลการ cut traffic sila 26052016.gslides'
# 'CV Chakrit.gdoc'
#  CV.gdoc
#  d1_01_SOW.gdoc
# 'Dashboard for 24 shopping.xlsx'
#  data
#  data2.gdoc
# 'Data base compare table.gsheet'
# 'Data .gdoc'
#  Day1.pptx.gslides
#  Day3.pptx.gslides
# 'Day 4.pptx'
# 'Day 4.pptx.gslides'
#  debug.ods.gsheet
#  DEC-ALL.ods
#  delete.gdoc
#  Designer-Components.pdf
# 'Designer-Getting-Started (1).pdf'
#  Designer-Getting-Started.pdf
# 'Design Network Hadoop TAT V1.htm'
#  Detail_Training_Softnix_Logger_6hr.doc
#  Detail_Training_Softnix_Logger_6hr.doc.gdoc
# 'Developer SoftNIX.gsheet'
#  DevelopWorkFlow_v0.1.html
# 'Device List -App port reviewed 29Aug16_Final_softnix.xlsx'
# 'Devices Info.xlsx'
# 'Devices Info.xlsx.gsheet'
#  dev_skill_matrix.xlsx
#  dev_skill_matrix.xlsx.gsheet
# 'DevTeam Report 2018.gsheet'
#  disruptive-possibilities.epub
#  disruptive-possibilities.pdf
#  dm
#  dm1.gsheet
#  dm6G9v.pdf
#  dm_factor.gsheet
#  dm_global.gsheet
# 'DNM Requirement & Plan 15112013.gsheet'
#  เอกสารเซ็นต์ตรวจรับงาน.doc
#  เอกสารเซ็นต์ตรวจรับงาน.doc.gdoc
#  หน้าสอง_ด้านหน้า.docx
#  แจ้งผลอนุมัติ.docx
#  doubleA
#  DQ5
# 'Draft_SBN_CGN_logging_2014_RFP_Part_II_V1 1.doc'
# 'Draft_SBN_CGN_logging_2014_RFP_Part_II_V1 1.doc.gdoc'
# 'Dtac Calculator.gsheet'
#  EAPTLS.pdf
#  ebook
# 'Elasticsearch Training.docx'
# 'Elasticsearch Training.gdoc'
# 'Email Outbound Policy.gdoc'
#  EQ.gdoc
# 'Event Log (1) (1).xlsx.gsheet'
# 'Event Log (1).xlsx'
# 'Event Log (1).xlsx.gsheet'
# 'Event Log.xlsx'
# 'Event Registration.gform'
#  evoluate.gsheet
# 'Evoluate tools สำหรับทดลองงาน 3  เดือน.gsheet'
# 'Example Log RMV.gdoc'
# 'Example Log RMV.txt'
#  ExportSchoolClickEdu_2.xlsx
# 'EZ Note'
#  family
#  FATC_Rev2.doc
#  FATC_Rev2.doc.gdoc
#  FiiBackup
#  File_000.png
#  File_001.png
#  flight.gdoc
#  flowplayer.gdoc
# 'functional org.gslides'
#  Funding_Application.gdoc
# 'GCP Test Page.pdf'
#  ดวง.gdoc
#  ปปช.gdoc
#  สถิติ.gdoc
#  คุณชาคริต.gdoc
#  สรุปประจำปี.gdoc
#  เด็กดีทอดกถิน.gdoc
#  รายการสั่งของเอ๋.gdoc
#  ghm
# 'gi_port_assignment updated_suk_04022014 (1).gsheet'
# 'gi_port_assignment updated_suk_04022014.gsheet'
# 'Gi_port_assignment updated_suk_04022014.xlsx.gsheet'
# 'gi_port_assignment updated_suk_11122013 (1).gsheet'
# 'gi_port_assignment updated_suk_11122013 (2).gsheet'
# 'gi_port_assignment updated_suk_11122013 (3).gsheet'
# 'gi_port_assignment updated_suk_11122013.gsheet'
# 'gi_port_assignment updated_suk_17112013.gsheet'
# 'gi_port_assignment updated_suk_22112013.gsheet'
# 'gi_port_assignment updated_suk_22112013.xlsx'
# 'Gi_port_assignment updated.xlsx'
#  GISMAP_MOJ_MOCKUP.html
#  บ้าน.gmap
# 'กรมทางหลวงชนบท กระทรวงคมนาคม.gmap'
# 'Google Buzz'
# 'การใช้งาน GPG.gdoc'
# 'Grafana Dashboard User Acceptance Test CP-ALL-rev-1.docx.gdoc'
#  grafio
# 'grandmother (1).gsheet'
#  grandmother.gsheet
#  graphlist.gtable
#  Grokking_Algorithms.pdf
# 'Group Office Presentation.gslides'
# '_________ __________.gsheet'
#  ธอส.gsheet
# 'ราคา โทรศัพท์.gsheet'
#  หุ้น.gsheet
# 'แผนที่ รังสิต.gsheet'
#  ลูกค้า.gsheet
#  คิดดอก.gsheet
#  ไม้น้ำ.gsheet
#  แต่งบ้าน.gsheet
#  แผนค่าใช้จ่าย.gsheet
#  หนี้บัตรเครดิต.gsheet
#  แผนการดำเนินงาน.gsheet
#  ค่าใช้จ่ายพ่อแม่.gsheet
#  สเปรดชีตไม่มีชื่อ.gsheet
#  รายการค่าใช้จ่ายจีน.gsheet
#  ค่าใช้จ่ายเดือนธันวาคม.gsheet
#  แบบร่างการคิดเงินเดือน.gsheet
#  คำนวนค่าใช้จ่ายรายเดือน.gsheet
#  งานนำเสนอไม่มีชื่อ.gslides
#  hadoop
# 'hadoop (1)'
#  hadoop_architecture.pptx.gslides
# 'Hadoop Essential course.zip'
#  hadoop.gslides
#  hadoop_network_diagram.html
#  hadoop_sequence2.2.html
#  hadoop_sequence2.4.html
#  hadoop_sequence2.5.html
#  hadoop_sequence.html
#  hana.gdoc
#  hardening
# 'Hardinfo AIS.gsheet'
# 'HCGN RBAC.gsheet'
#  HCGN_Verify_lzo_and_parquet_table.gdoc
#  history_extract_transform_result.xlsx
#  history_extract_transform_result.xlsx.gsheet
#  Homework.gsheet
#  hostbangkok
#  hostbangkok_diagram_2014_07_22.png
# 'ราคา hosting.gsheet'
#  hostnbangkok_diagram_2014_07_22_rev2.png
#  hotelsin_gapore.jpg
# 'How To Communication .pptx'
# 'How to download youtube.gdoc'
# 'How to install Hadoop client.gslides'
# 'How to install tightvncserver .gdoc'
# 'howto squid to syslog-ng.gdoc'
#  hr
# 'HR info.gdoc'
#  HR.pptx
#  HR.pptx.gslides
#  Hsri
# 'HSRI presentation.gslides'
# 'HSRI Schedule Plain move data to NFS.gsheet'
#  แบบแผนที่ยังไม่ได้ตั้งชื่อ.html
# 'Human Resource.gslides'
#  icc.gsheet
#  iching.gsheet
# 'ICT กรมทางหลวง.doc'
#  idcard
#  ILO_01
#  image.jpg
#  IMG_0781.PNG
#  IMG_1042.JPG
#  IMG_1650.JPG
# 'Implement Plan AIS Phase 3_02022015.gsheet'
# 'Implement Plan AIS Phase 3_02022015.xlsx'
# 'Implement Plan AIS Phase 3_02022015.xlsx.gsheet'
# 'Implement Plan AIS Phase 3_04022015.gsheet'
# 'Implement Plan.gsheet'
#  import
# 'Imported from Google Notebook - สมุดบันทึก 1.gdoc'
# 'Imported from Google Notebook - พี่เสือ ไฟ cateye.gdoc'
# 'Imported from Google Notebook - ประชุม อสค.gdoc'
# 'Imported from Google Notebook - My first notebook.gdoc'
# 'Incident Clarification.gslides'
# 'ขั้นตอนการ Index.gslides'
#  infosec.html
#  infosec-Prj
# 'Innovation Continuity Canvas by RISE V1_0.gdoc'
#  introduction-to-algorithms-3rd-edition.pdf
#  Invoice.pdf
#  IOT_forTrue.drawio
#  iot_training
# 'วิธีเปลี่ยน IP บน ESX.docx'
# 'ipmx_Example Log report.docx'
#  iso29110
#  iso29110.gsheet
#  Itinerary_88538351.pdf
#  itmx
# 'itmx centralized log rfp comply table for poc rs updated v01_20140515 (1).gsheet'
# 'itmx centralized log rfp comply table for poc rs updated v01_20140515.gsheet'
# 'ITMX Centralized Log RFP Comply table For POC RS updated V01_20140515.xlsx'
# 'ITMX Centralized Log RFP Comply table For POC RS updated V01_20140520 (1).xlsx'
# 'ITMX Centralized Log RFP Comply table For POC RS updated V01_20140520 (2).xlsx'
# 'ITMX Centralized Log RFP Comply table For POC RS updated V01_20140520 (3).xlsx'
# 'ITMX Centralized Log RFP Comply table For POC RS updated V01_20140520 (4).xlsx'
# 'ITMX Centralized Log RFP Comply table For POC RS updated V01_20140520 (5).xlsx'
# 'ITMX Centralized Log RFP Comply table For POC RS updated V01_20140520 (6).xlsx'
# 'ITMX Centralized Log RFP Comply table For POC RS updated V01_20140520.xlsx'
# 'IT Security Workshop.gdoc'
#  JD.gslides
#  JUN-ALL-2014_report2.gsheet
#  JUN-ALL-2014_report2.xlsx
#  JUN-ALL-2014.xlsx
#  kafka_scale.gsheet
# 'KB (1).jpg'
#  KBGC_1000000029365671_150510.pdf
#  KBSS_1000000029365671_201403.pdf
# 'Kick off_CGN Log_201402012 (1).pptx.gslides'
# 'Kick off_CGN Log_201402012.pptx'
# 'Kick off_CGN Log_201402012.pptx.gslides'
#  kico.co.th_v2.gdoc
#  King
#  KIXCZ-JP009_-โอซาก้า-เกียวโต-โกเบ-ยูนิเวอร์แซล-5D4N-_-CZ_29-ธ.ค-2-ม.ค57-_43900.--1.pdf
# 'Kleasing-Device List Fill in POC 201406 (2) (1).gsheet'
#  kpi
#  KPI.gslides
# 'KPI Softnix 2013_Service.xlsx.gsheet'
#  KSQL_concept.html
# 'ขั้นตอนการ LAB test  Backup Restore Database.gsheet'
#  LessionLearn
#  line
# ' List Softnix Logger NSTDA 072015.xlsx.gsheet'
#  litemail.gdoc
#  local0_info_172.17.1.4_201612151459.log.tgz
#  localhost_new.sql
# 'log2 (3).csv.gsheet'
# 'ปริมาณ Log ของ AIS CWDC.gdoc'
# 'Log Collector Monitoring.docx'
# 'Logger Enterprise csp (1).gsheet'
#  logger_report_True_CTL_PBI_V1.1.doc
#  logger_report_True_CTL_PBI_V1.1.doc.gdoc
# 'logindex performance testing.gsheet'
# 'log information and location (1).gsheet'
# 'log information and location (2).gsheet'
# 'log information and location.gsheet'
# 'วิธีการ เพิ่ม Log เมื่อมี log เข้ามาใหม่.gslides'
#  log_report
# 'Log search for docsis and wifi.gslides'
# 'Log Search User Manual V1.0.gdoc'
#  Lucidchart
#  lz4_93_2012-01-28.gsheet
#  lz4_93_27.gsheet
#  lz4_94_2012-01-28.gsheet
# 'LZ4 Performance Testing v3.gsheet'
# 'ใช้อธิบาย Machine Learning.gsheet'
#  market_vos-DLF4.xlsx
#  master
#  mib_ais_2.gsheet
#  mibs.gsheet
#  mibs.xlsx
# 'Microservice paper.doc'
#  microservice_thesis
#  Middleton-Baeza.pdf
# 'ผลการ Migrate Script ครั้งที่ 3  SUK@2,3,8.gslides'
# 'ผลการ Migrate Script ครั้งที่ 4 และ change core cpu SUK v3.gslides'
# 'ผลการ Migrate Script ครั้งที่ 5 และ change core cpu CWDC.gslides'
# 'ผลการ Migrate Script ครั้งที่ 6change core cpu TLS version 2.gslides'
#  MindMeister
# 'Minute Of Meeting.gdoc'
# 'Mirror log  restore v1.0.gslides'
# 'Module Search support for Juniper new log format_20150706.gsheet'
#  moj2
#  money2.gsheet
# 'Money Lover - export'
#  Mongodb.gslides
#  mongodb_open_source_high_performance_database.gslides
#  Mongo_RIAUnleashed_2010.gslides
# 'Monthly budget (1).gsheet'
# 'Monthly budget (2).gsheet'
# 'Monthly budget.gsheet'
#  Monthly.gsheet
#  mps3bb.gsheet
#  mps3bb.ods
#  m-society
# 'การทดสอบ Multiprocess lz4 .gsheet'
#  mysql_3_replicate
# 'Mysql Cluster Howto from top.gdoc'
# 'My Tracks'
#  MyWallet-2015-05-18@07.56.02.bwall
#  NACC.gdoc
#  Naivebayes.gsheet
# 'NAS Storage Report.gdoc'
# 'NAS table list.gsheet'
#  NCA.pdf
#  nectec
# 'Nectec Standard Clearly.docx'
# 'Nectec Standard Clearly.docx.gdoc'
#  Neo4j
#  network_bonding_test.gsheet
#  new-line-true.gsheet
# 'New office.xlsx'
# 'แผนการตลาด New product.gdoc'
# 'New Salary.xlsx'
# 'new table details (Recovered).gdoc'
# 'New Table.gtable'
#  nikon
# 'nikon (1)'
#  Nikon-SSL-Schedule-task.gsheet
# 'NMS-WEB Error.gdoc'
#  Notability
# 'Note Jul 4, 2559 BE 3_03_28 PM.pdf'
# 'Note Sep 3, 2559 BE อ. ณัติวุฒ.zip'
#  nstda
#  nstda1.pptx.gslides
# 'การติดตั้ง NXlog for windows และ linux.gdoc'
#  OCT-ALL-2013.gsheet
#  เซ็ตราคาคอม.ods.gsheet
# 'OID Softnix Logger CGN 04082015_v2.gsheet'
# 'OID Softnix Logger HCGN 0082015.gsheet'
# 'OID Softnix Logger HCGN 04082015_v2.gsheet'
# 'OID Softnix Logger HCGN 04082015_v2.xlsx'
# 'OID Softnix Logger HCGN 04082015_v2.xlsx.gsheet'
# 'OID Softnix Logger HCGN 15062015.gsheet'
# 'OID Softnix Logger HCGN 15062015.xlsx'
# 'OID Softnix Logger HCGN 15062015.xlsx.gsheet'
#  onec022013.xls.gsheet
#  OperationguideCPALL20122014.docx.gdoc
# 'orcids (1).zip'
#  orcids.zip
# 'Order 2557.xlsx'
# 'Order 2557.xlsx.gsheet'
#  orgchart.html
# 'OrgChartR&D.drawio'
#  Others
#  Outlook
#  P_20140916_173605_HDR.jpg
# 'Palo any & unknow v1.0.gslides'
#  Paper_V1.0.docx
#  pat.docx
#  pat.docx.gdoc
#  pat-node4.docx
#  pat-node4.docx.gdoc
# 'pat-node7 (1).gdoc'
# 'pat-node7 (2).gdoc'
#  pat-node7.docx
#  pat-node7.gdoc
# 'นสพ.เดลินิวส์ ฉบับ ร.๙ ทั้งฉบับ.pdf'
#  หน้าสอง_ด้านหน้า.pdf
#  หน้าสอง_ด้านหลัง.pdf
#  แผนรองรับ.pdf
#  คู่มือกล้องไร้สาย.pdf
#  pentaho
# 'pentaho (1)'
#  perfect_place
# 'Performance AIS.gsheet'
# 'performance evolution.gslides'
# 'Performance Monitoring.pptx.gslides'
# 'Performance Review of CGN Log FEB.pptx.gslides'
# 'Performance Review of CGN Log Jan 2016.gslides'
# 'Performance Review of CGN Log JAN.pptx.gslides'
# 'Performance Review of CGN Log June_04072016.gslides'
# 'Performance Review of CGN Log June_04072016.pptx'
# 'Performance Review of CGN Log June_04072016.pptx.gslides'
# 'Performance Review of CGN Log June_04072016 update 06072016.gslides'
# 'Performance Review of CGN Log MAY_160559.pptx'
# 'Performance Review of CGN Log MAY_160559.pptx.gslides'
# 'Performance Review of CGN Log MAY.pptx'
# 'Performance Review of CGN Log MAY.pptx.gslides'
# 'Performance Review of CGN Log.pptx'
# 'Performance Review of CGN Log.pptx.gslides'
# 'Performance syslog-ng.gsheet'
# 'Performance syslog-ng-hdparm.gtable'
# 'Performance syslog-ng-Sheet2.gtable'
# 'performance test.gdoc'
# 'Performance testing syslog-ng 3.2 , 3.7.gdoc'
#  phparch
# 'ข้อสอบ php สมัครงาน.gdoc'
# 'PHP Quiz Script.png'
#  Pitch.gslides
# 'P&L เดือน 10 (ต.ค.) 2558-2015.xlsx'
# 'P&L เดือน 10 (ต.ค.) 2558-2015.xlsx.gsheet'
#  place.gsheet
# 'Plan for Purge data02092015.gsheet'
# 'Plan for Purge data.xlsx'
# 'Plan for Purge data.xlsx.gsheet'
#  pmp
#  pmp6.png
#  POC_CGN_logging_softnix.xlsx.gsheet
# 'POC DTAC 24042014.gslides'
# 'POC Functional & Performance Test_20141021.docx'
# 'POC Functional & Performance Test_20141021.docx.gdoc'
# 'POC Functional & Performance Test_20141103.docx'
# 'POC Functional & Performance Test_20141103.docx.gdoc'
# 'POC HA_20141021.docx'
# 'POC HA_20141021.docx.gdoc'
# 'POC HA_20141024.docx'
# 'POC HA_20141024.docx.gdoc'
# 'ศิริราช_POC_logger (1).gdoc'
# 'POC Summary v1.pptx'
# 'port and ip address - 27 june 2013.gsheet'
# 'Port check summary 062014.gsheet'
#  pplus-multiple-query-mockup.gslides
# 'pplus node 4.html'
#  PPlusPATSoftnixLogger.gdoc
#  PP-ZABBIX-CPALL-2017.gsheet
# 'Presentation1 (1).pptx'
# 'Presentation1 (1).pptx.gslides'
#  Presentation.gslides
#  Presentation_provider_final.pptx.gslides
#  Present_softnix_ldap.ppt
#  Present_softnix_ldap.ppt.gslides
# 'Press Space or double-click to edit (1).mup'
# 'Press Space or double-click to edit.mup'
#  price
# 'price list update on 2 oct 09 (dealer).gsheet'
# 'Procedure 3bb Softnix Logger Aggregator Backup 08092015.gsheet'
#  project
# 'Project Charter POC Softnix logger hadoop PPlus (1).gdoc'
#  ProjectCharterPOCSoftnixloggerhadoopPPlus.docx
#  ProjectCharterPOCSoftnixloggerhadoopPPlus.docx.gdoc
# 'Project Charter POC Softnix logger hadoop PPlus.gdoc'
# 'Project Management process Present v1.0.2.pptx'
# 'Project Wireframes.gslides'
#  ProjID_Proj-Mgt-Plan_v1-0.doc.gdoc
# 'PROPOSAL_Log_สำนักงานปลัดกระทรวงกลาโหม (1).gdoc'
#  pythondatasciencehandbook.pdf
# 'PyTorch Lab 2 - XOR.ipynb'
#  qh.gdoc
# 'ผลการ Query AGG3.gdoc'
# 'quick save.gsheet'
#  quota_limit.xls.gsheet
# 'Quotation - Order (42).pdf'
#  rayong
#  RBAC_CH7.gsheet
# 'RBAC Modules Descriptions (1).gsheet'
# 'RBAC Modules Descriptions.gsheet'
#  read.docx.gdoc
#  realfeature_truemove_new_juniper_format.gsheet
# 'Report AIS CGN.gslides'
# 'Report .gdoc'
# 'report storage AIS.xlsx'
# 'report storage AIS.xlsx.gsheet'
# 'Requirement Specification พี่ปู.gsheet'
#  research_methods
#  resume
#  RFP_2_Solution_CentralisedSYSLOG.gsheet
# 'RFP_CGN Log 2014_Compliance_softnix_v2.gsheet'
#  RFP.gsheet
# 'RFT LOG TYN Syslog Parameter Version 1.0.xlsx.gsheet'
# 'RFT-MPDN for Log System_High-Level System Design _HLSD_ V1.1.pdf'
# 'RMV Node 5 Syslog Network Diagram ver2.1 (1).vsdx'
# 'RMV Node 6 Softnix Logger Server - PAT V1.2.gdoc'
# 'Sales Order 2558.xlsx'
# 'Sales Order 2558.xlsx.gsheet'
# 'Sawmill Administrator Training.pptx'
# 'Sawmill Administrator Training.pptx.gslides'
# 'Sawmill Features.gdoc'
# 'ขั้นตอนการเปลี่ยนปีให้ตรงกันสำหรับ sawmill.gslides'
#  SBNCGNProject_PhaseI_FAT_R2_25072016_v2.gdoc
# 'SBNCGNProject_PhaseI_FAT_R2_27062016 (1).doc.docx.gdoc'
#  SBNCGNProject_PhaseI_FAT_R2_27062016.doc.docx
#  SBNCGNProject_PhaseI_FAT_R2_27062016.doc.docx.gdoc
# 'SBN CGN Project_Phase I_FAT_R2.doc'
# 'SBN CGN Project_Phase I_FAT_R2.doc.gdoc'
# 'SBN CGN Project_Phase II_FAT_softnix_v2_.doc.gdoc'
#  SchedulePlain.gsheet
# 'Schedule Plan cpall DM v1.0_16052016.xlsx.gsheet'
# 'Schedule Plan cpall DM v1.0_23062016.xlsx'
# 'Schedule Plan cpall DM v1.0_23062016.xlsx.gsheet'
# 'Schedule Plan cpall DM v1.0_26052016.xlsx'
# 'Schedule Plan cpall DM v1.0_26052016.xlsx.gsheet'
# 'Schedule Plan cpall Phase2 v2.1 (1).xlsx.gsheet'
# 'Schedule Plan cpall Phase2 v2.1.xlsx.gsheet'
# 'Science fair.gslides'
# 'scope of works ais phase 3.gdoc'
# 'Scope of work v1.2.docx'
# 'Scope of work v1.2.docx.gdoc'
#  Scratchpad
#  Screenshot-2.png
# 'Screen Shot Modules Name.pptx'
#  Screenshots_2014-04-22-00-49-41.png
# 'การใช้งาน script export.gdoc'
# 'script ส่ง log.gdoc'
# 'Script Search command to csv.gdoc'
# 'การ Search Log.gdoc'
# 'การ Search Log.gslides'
#  security
#  Selection_122.png
#  Sequence_hadoop
#  service_exam
# 'แผน Services ปี 2554.gslides'
#  services.mup
# 'การ set link aggregate + tag vlan ให้กับ esxi.gdoc'
# 'การ set quota linux.gdoc'
# 'ผลการ Shutdown collector SUK 4 version 1.1 .gslides'
# 'Simulation Termination.gslides'
#  Singapore
# 'singapore travel.gsheet'
#  sitebuilder-4.5-templates-guide.pdf
#  sitebuilder-4.5-win-wizard-users-guide.pdf
# 'size hadoop ais.xlsx'
# 'size hadoop ais.xlsx.gsheet'
#  size_suk062014.gsheet
#  SLG_a10_performance.gslides
#  SLG_CGN_Public.gslides
#  SLG-CLOUD-Draft.gantter
# 'SLG_Present_2013 (1).pptx.gslides'
# 'SLG_Present_2013 (2).pptx.gslides'
#  SLG_Present_2013.gslides
#  SLG_Present_2013.pptx.gslides
#  SLG_Present_2014.gslides
#  SLG_Present_Partner_Private.odp
#  SLG_Present_Partner_public.ppt
#  SLG_Present_Partner_public.ppt.gslides
#  SLG_Trainig_NOC.gslides
#  SLG_Trainig_SLG5.1.gslides
#  SLG_Trainig_SLG6.3.gslides
#  SLG_Trainig_SLG6_3hr-6.ppt.gslides
# 'sls import format.gsheet'
#  SMS_Admin_3hr.pptx.gslides
#  sna
#  sna_prj3
# 'Snare and epilog Agent install v1.0.gslides'
# 'SNMP fragment _IPv4_OID.gsheet'
#  snmp.tar.gz
#  softixtheme.gslides
#  softnix
#  Softnix
#  softnix2.gmap
#  softnix_cgn_flow_diagram.html
# 'Softnix Data Platform - 1.png'
# 'softnix_dev (1).pptx.gslides'
#  Softnix_Develop_WorkFlow
#  softnix_dev.pptx.gslides
# 'softnix diagram.html'
# 'softnix examination ลองทำดูครับ.gdoc'
#  Softnix_FATC_SoftnixLogger_cgn_logger.docx
#  Softnix_FATC_SoftnixLogger_cgn_logger.gdoc
#  softnix.gdoc
#  softnix.gmap
#  softnix_informations
# 'Softnix - JD -  Developer.gsheet'
# 'คู่มือ Softnix Logger 3-07-2015.doc'
# 'softnix logger aggegrator hardening checklist ver1.1 (1).gsheet'
# 'softnix logger aggegrator hardening checklist ver1.1.gsheet'
#  softnixLogger-architech
# 'softnix logger collector hardening checklist ver1.1 (1).gsheet'
# 'softnix logger collector hardening checklist ver1.1.gsheet'
# 'Softnix Logger course outline for real move.gdoc'
# 'softnixlogger crontab .gdoc'
# 'softnixlogger crontab V 6.0.5.gdoc'
# 'Softnix Logger Features.gslides'
# 'Softnix Logger flow process.gdoc'
# 'Softnix Logger for 3BB report 12022014.gdoc'
# 'การติดตั้ง Softnix Logger.gdoc'
# 'แผนการทดสอบ Softnix Logger .gsheet'
# 'เรามีความรู้อะไรเกี่ยวกับ Softnix Logger.gsheet'
# 'Softnix Logger Original'
# 'Softnix Logger.png'
#  SoftnixLoggerswitchtoSUKProcedure.docx
# 'Softnix Logger syslog-ng performance test.gdoc'
# 'SoftnixLogger Training'
# 'Softnix Logger true testing.gsheet'
# 'Softnix PHP exam.gdoc'
# 'Softnix Product brief 2012.pptx.gslides'
#  SoftnixProducts.pptx.gslides
#  Softskill
# 'Software Design Specification v1.0.docx.gdoc'
# 'Software Maintenance_3BB_NAT444 Report_2nd 2014.docx.gdoc'
# 'Software process2018.gslides'
# 'Software process.gslides'
# 'Software Process.html'
# 'Software process_v2 (1).key'
# 'Solution_BigData v3.pdf'
# 'Solution Compare.pptx'
# 'S&P โลตัส สุขาภิบาล1 (1).gmap'
# 'S&P โลตัส สุขาภิบาล1.gmap'
# 'SRT-DataGov-ปิดโครงการ Rev_01.pdf'
# 'SRT-DataGov-ปิดโครงการ Rev_01.pptx'
#  ssup
# 'ssup (1)'
#  standby_issue.JPG
# 'stats for datascience.gdoc'
# 'Status Update.gslides'
# 'Step Change Configuration for all Device.xlsx'
#  stock_test.gsheet
#  Storage_map_position_AIS.xlsx.gsheet
# 'Storage Size 25052014.gdoc'
# 'storge ais.gsheet'
# 'Stroage 180 days (1).gsheet'
# 'Stroage 180 days (2).gsheet'
# 'stroage 180 days.gsheet'
# 'Stroage 180 days.gsheet'
# 'Stroage 180 days.xlsx'
#  sukanya
#  summary27-01-2013.gsheet
# 'summary27-01-2013_rev2 (1).gsheet'
#  summary27-01-2013_rev2.gsheet
#  summary29-01-2013.gsheet
#  summary30-01-2013.gsheet
#  Summary_-_DataStructure_and_Algorithm.pdf
# 'ขั้นตอนการ Switch Softnix Logger Aggregator  to Softnix Logger Aggergator Backup.gdoc'
#  syllabus.pdf
# 'syslog calculator.gsheet'
# 'Syslog Configuration_update20131220.gslides'
# 'Syslog-ng for True 2020.v2.gsheet'
# 'Syslog-ng Performance.gdoc'
# 'syslog-ng performance test (1).gsheet'
# 'syslog-ng performance test.gdoc'
# 'syslog-ng performance test.gsheet'
# 'syslog-ng-performance test.gsheet'
# 'Syslog-ng Test Best Test.gsheet'
# 'Syslog-ng TLS.gdoc'
#  SyslogTestPerformance2020.drawio
# 'System Summary v11 15jan2013-v3.pptx.gslides'
# 'Table for Softnix (1).xlsx.gsheet'
# 'Table for Softnix (2).xlsx.gsheet'
# 'Table for Softnix.xlsx'
# 'Table for Softnix.xlsx.gsheet'
# 'table json format Softnix.docx'
#  table_stats_mobile3g.csv
#  table_stats_mobile3g.csv.gsheet
# 'Talend Big Data Integration day2.pdf'
# 'Task Day1.pptx.gslides'
# 'Task List_Softnix_26042013.docx'
#  task.xlsx
#  task.xlsx.gsheet
#  tat_bigdata_rscript.html
#  tat_hive_table.html
# 'TAT Smart Migration.drawio'
#  TATSMigrate.drawio
#  tax_car_sukan07112015.pdf
#  TCS
# 'Template for TOR Comply of Log Aggregator.xlsx.gsheet'
# 'Template for TOR Comply of Log Collector (1).xlsx.gsheet'
# 'Template for TOR Comply of Log Collector (2).xlsx.gsheet'
# 'Template for TOR Comply of Log Collector.xlsx'
# 'Template for TOR Comply of Log Collector.xlsx.gsheet'
#  template.gsheet
# 'template syslog Performance test 3.2-3.7.gsheet'
#  test_open_google_doc.gsheet
#  textClassification.drawio
#  text.gdoc
#  thesis
#  Thesis2
#  thesis_evoluate.gsheet
#  ThesisMilk.drawio
#  Ticket-10-2013.gsheet
#  tint
#  TLN.ipynb
#  tls.csv
#  tls.gsheet
#  TLS.gsheet
#  tmp
# 'tmp calc.gsheet'
#  tmp.gsheet
#  tom.pptx
# 'TOR Filtering_Log.pdf'
# 'TOR for Compliance Log Storage for Customers_v2.gsheet'
# 'TOT  Cofiguration Training จากฟลุค.gdoc'
#  tour
# 'Tourism Smart Data - Maintenance Period Monthly report - April 2020 - Softnix.gdoc'
#  Training
# 'สรุปงาน training bigdata 24 jan 2018.gdoc'
# 'Training Softnix Data Platform v1.2.gslides'
# 'Training TCS.gslides'
# 'Transaction 6month.gsheet'
#  transformFBB_v1.rar
#  trigger_AIS_HCGN_version3.0.xlsx.gsheet
#  trigger_AIS.xlsx
#  trigger_AIS.xlsx.gsheet
#  true1
# 'TRUE BB CGN - Softnix - Provisional Acceptance Test V1.0.pdf'
#  TrueBladeTest.pptx
# 'true งานวันพรุ่งนี้.gdoc'
# 'true ปัญหาที่ต้องแก้ให้ทัน.gsheet'
#  TrueInternet2
#  TrueInternetTraining
#  True-link-action2.gsheet
#  True-link-action.gsheet
#  truemoveh_4g
# 'TrueMove node 4 IP list.gsheet'
#  truemove_p_ekasit
#  truemove_PPlus
# 'True Node 4_2.gantter'
# 'True Node 5.gantter'
#  true_realfeature_3
# 'True template.gantter'
#  tuanjai.gsheet
#  TUC
#  tuc1.html
# 'การ tuning sawmill ลดเวลาในการ index.gslides'
# 'uat approval (1).gsheet'
# 'uat approval.20140103.gsheet'
# 'uat approval.gsheet'
# 'UAT Approval.xlsx'
#  UAT_CGN_201507201100.gdoc
#  UAT_CGN_201508112000.docx
#  UAT_CGN_201508112000.docx.gdoc
# 'UAT_CGN_201508251500(HA).docx.gdoc'
#  UAT_CGN_Collector_20150814.gdoc
#  UAT_CGN_Collector_20150814_v1.gdoc
# 'UAT Collector Copperate Log version 2.0.gdoc'
# 'UAT Document.docx.gdoc'
# 'UAT_EDS_Collector_20160621 (1).docx'
# 'UAT_EDS_Collector_20160621 (1).docx.gdoc'
#  UAT_EDS_Collector_20160621.docx
#  UAT_EDS_Collector_20160621.docx.gdoc
#  Untitled3.csv
#  Untitled3.gsheet
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram (1).html'
# 'Untitled Diagram (2).drawio'
# 'Untitled Diagram (2).html'
# 'Untitled Diagram (3).html'
# 'Untitled Diagram (4).html'
# 'Untitled Diagram (5).html'
# 'Untitled Diagram (6).html'
# 'Untitled Diagram (7).html'
# 'Untitled Diagram (8).html'
# 'Untitled Diagram.drawio'
# 'Untitled Diagram.html'
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled drawing (1).gdraw'
# 'Untitled drawing.gdraw'
# 'Untitled form (1).gsheet'
# 'Untitled form [Form] (1).gform'
# 'Untitled form [Form].gform'
# 'Untitled form.gsheet'
#  Untitled.gantter
#  Untitled.gmap
# 'Untitled presentation (10).gslides'
# 'Untitled presentation (11).gslides'
# 'Untitled presentation (12).gslides'
# 'Untitled presentation (13).gslides'
# 'Untitled presentation (14).gslides'
# 'Untitled presentation (15).gslides'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation (2).gslides'
# 'Untitled presentation (3).gslides'
# 'Untitled presentation (4).gslides'
# 'Untitled presentation (5).gslides'
# 'Untitled presentation (6).gslides'
# 'Untitled presentation (7).gslides'
# 'Untitled presentation (8).gslides'
# 'Untitled presentation (9).gslides'
# 'Untitled presentation.gslides'
# 'Untitled Presentation.gslides'
# 'Untitled spreadsheet (10).gsheet'
# 'Untitled spreadsheet (11).gsheet'
# 'Untitled spreadsheet (12).gsheet'
# 'Untitled spreadsheet (13).gsheet'
# 'Untitled spreadsheet (14).gsheet'
# 'Untitled spreadsheet (15).gsheet'
# 'Untitled spreadsheet (16).gsheet'
# 'Untitled spreadsheet (17).gsheet'
# 'Untitled spreadsheet (18).gsheet'
# 'Untitled spreadsheet (19).gsheet'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (20).gsheet'
# 'Untitled spreadsheet (21).gsheet'
# 'Untitled spreadsheet (22).gsheet'
# 'Untitled spreadsheet (23).gsheet'
# 'Untitled spreadsheet (24).gsheet'
# 'Untitled spreadsheet (25).gsheet'
# 'Untitled spreadsheet (26).gsheet'
# 'Untitled spreadsheet (27).gsheet'
# 'Untitled spreadsheet (28).gsheet'
# 'Untitled spreadsheet (29).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (30).gsheet'
# 'Untitled spreadsheet (31).gsheet'
# 'Untitled spreadsheet (32).gsheet'
# 'Untitled spreadsheet (33).gsheet'
# 'Untitled spreadsheet (34).gsheet'
# 'Untitled spreadsheet (35).gsheet'
# 'Untitled spreadsheet (36).gsheet'
# 'Untitled spreadsheet (37).gsheet'
# 'Untitled spreadsheet (38).gsheet'
# 'Untitled spreadsheet (39).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (40).gsheet'
# 'Untitled spreadsheet (41).gsheet'
# 'Untitled spreadsheet (42).gsheet'
# 'Untitled spreadsheet (43).gsheet'
# 'Untitled spreadsheet (44).gsheet'
# 'Untitled spreadsheet (45).gsheet'
# 'Untitled spreadsheet (46).gsheet'
# 'Untitled spreadsheet (47).gsheet'
# 'Untitled spreadsheet (48).gsheet'
# 'Untitled spreadsheet (49).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (50).gsheet'
# 'Untitled spreadsheet (51).gsheet'
# 'Untitled spreadsheet (52).gsheet'
# 'Untitled spreadsheet (53).gsheet'
# 'Untitled spreadsheet (54).gsheet'
# 'Untitled spreadsheet (55).gsheet'
# 'Untitled spreadsheet (56).gsheet'
# 'Untitled spreadsheet (57).gsheet'
# 'Untitled spreadsheet (58).gsheet'
# 'Untitled spreadsheet (59).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet (60).gsheet'
# 'Untitled spreadsheet (61).gsheet'
# 'Untitled spreadsheet (62).gsheet'
# 'Untitled spreadsheet (63).gsheet'
# 'Untitled spreadsheet (64).gsheet'
# 'Untitled spreadsheet (65).gsheet'
# 'Untitled spreadsheet (66).gsheet'
# 'Untitled spreadsheet (6).gsheet'
# 'Untitled spreadsheet (7).gsheet'
# 'Untitled spreadsheet (8).gsheet'
# 'Untitled spreadsheet (9).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'ขั้นตอนการ Update Kernel .gsheet'
# 'Update WebUI support WIFI.gsheet'
# 'Use Case Diagram.gslides'
# 'User Acceptance Test Zabbix CP-ALL.docx'
# 'User Acceptance Test Zabbix CP-ALL.docx.gdoc'
#  UserData-mogen.co.th-20140813.gsheet
# 'User Password HCGN.gsheet'
#  User_Training_CPALL.pptx
#  User_Training_CPALL.pptx.gslides
# 'visa letter1 bitedit.docx'
# 'visa letter 2.docx'
#  w2v
# 'WBS Details.gsheet'
# 'WBS Details.xlsx'
# 'แผนการดำเนินงานติดตั้ง WebApp .gsheet'
# 'ขั้นตอนการเข้าใช้งาน Web App_v1.gdoc'
# 'Web Data Extraction'
# 'Wedding (1).gslides'
# 'Wedding (2).gslides'
#  Wedding.gsheet
#  Wedding.gslides
#  wedding.mup
# 'WI  change IP .gsheet'
# 'WI การเพิ่ม Core CPU สำหรับ Collector site TLS.gdoc'
#  WI.gsheet
# 'WI hcgn add trim command & Remove Mobile4G,Mobile2G dropdown menu.gsheet'
# ' WI hcgn remove Mobile4G.gsheet'
# 'wi imei docs for admin.gdoc'
# 'WI_Merge Mobile Table_20160531_softnixupdate_v2.gsheet'
# 'WI_Merge Mobile Table_20160531_softnixupdate_v2.xlsx'
# 'WI_Merge Mobile Table_20160531_softnixupdate_v2.xlsx.gsheet'
# 'WI_Merge Mobile Table_20160531_softnixupdate.xlsx.gsheet'
# 'WI_Merge Mobile Table_20160531_softnixupdate.xlsx.xlsx'
# 'WI_Merge Mobile Table_20160531.xlsx'
# 'WI Module Search support for new log format_20150625.xlsx'
# 'WI Module Search support for new log format.gsheet'
#  WI_move_data_nas_storage.gdoc
#  wingwing.gsheet
#  wink
#  Wiring_List_SYSLOG.gsheet
# 'WI Share Traffic TLS to SILA.gsheet'
# 'Work & Life.pptx'
# '_________ __________.xls'
# '_________ __________.xls.gsheet'
#  ออมสิน.xls.gsheet
#  แผนการดำเนินงาน.xlsx
#  งบค่าใช้จ่าย.xlsx.gsheet
# 'z (1).csv'
# 'z (1).gsheet'
#  zabbix
#  zabbix_cpall_issue_1122016-2.pptx.gslides
#  zabbix_cpall_issue_1122016-2.pptx.pptx
#  zabbix_cpall_issue_1122016.key
# 'ZABBIX CPALL Meeting.pptx.gslides'
#  Zabbix_Design_1.0.pdf
#  zabbix_issue5.pptx.gslides
# 'Zabbix issue.gslides'
# 'Zabbix Monitoring CH7.gslides'
#  ZabbixNamingForDevice.pdf
# 'Zabbix_report_rev 001 (1).xlsx.gsheet'
# 'Zabbix_report_rev 001.xlsx'
# 'Zabbix_report_rev 001.xlsx.gsheet'
#  zabbixSizing.png
#  zabbix_training1d
#  zabbix_training5d
# 'Zabbix Training china.gdoc'
#  z.csv
#  zend-course-catalog-2010-3.pdf
#  zend-course-catalog-2010-4.pdf
#  Zend-PHP-5.3-Study-Guide-v1-3.pdf
#  z.gsheet
#  เรียนรู้เรื่องหุ้น.zip
#   ค่าบัตรเครดิต.gsheet

# %%
#!wget 
#!unzip
# !wget -cq https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
# !unzip -qq flower_data.zip

# %%
# !pip install python-twitter
# Out:
# Collecting python-twitter
#   Downloading https://files.pythonhosted.org/packages/b3/a9/2eb36853d8ca49a70482e2332aa5082e09b3180391671101b1612e3aeaf1/python_twitter-3.5-py2.py3-none-any.whl (67kB)
#      |████████████████████████████████| 71kB 2.1MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from python-twitter) (2.23.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.6/dist-packages (from python-twitter) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from python-twitter) (0.16.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (2020.4.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib->python-twitter) (3.1.0)
# Installing collected packages: python-twitter
# Successfully installed python-twitter-3.5

# %%
import twitter

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------------
# absl-py                  0.9.0
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   4.1.0
# asgiref                  3.2.7
# astor                    0.8.1
# astropy                  4.0.1.post1
# astunparse               1.6.3
# atari-py                 0.2.6
# atomicwrites             1.4.0
# attrs                    19.3.0
# audioread                2.1.8
# autograd                 1.3
# Babel                    2.8.0
# backcall                 0.1.0
# beautifulsoup4           4.6.3
# bleach                   3.1.5
# blis                     0.4.1
# bokeh                    1.4.0
# boto                     2.49.0
# boto3                    1.13.13
# botocore                 1.16.13
# Bottleneck               1.3.2
# branca                   0.4.1
# bs4                      0.0.1
# CacheControl             0.12.6
# cachetools               3.1.1
# catalogue                1.0.0
# certifi                  2020.4.5.1
# cffi                     1.14.0
# chainer                  6.5.0
# chardet                  3.0.4
# click                    7.1.2
# cloudpickle              1.3.0
# cmake                    3.12.0
# cmdstanpy                0.4.0
# colorlover               0.3.0
# community                1.0.0b1
# contextlib2              0.5.5
# convertdate              2.2.1
# coverage                 3.7.1
# coveralls                0.5
# crcmod                   1.7
# cufflinks                0.17.3
# cvxopt                   1.2.5
# cvxpy                    1.0.31
# cycler                   0.10.0
# cymem                    2.0.3
# Cython                   0.29.18
# daft                     0.0.4
# dask                     2.12.0
# dataclasses              0.7
# datascience              0.10.6
# decorator                4.4.2
# defusedxml               0.6.0
# descartes                1.1.0
# dill                     0.3.1.1
# distributed              1.25.3
# Django                   3.0.6
# dlib                     19.18.0
# docopt                   0.6.2
# docutils                 0.15.2
# dopamine-rl              1.0.5
# earthengine-api          0.1.221
# easydict                 1.9
# ecos                     2.0.7.post1
# editdistance             0.5.3
# en-core-web-sm           2.2.5
# entrypoints              0.3
# ephem                    3.7.7.1
# et-xmlfile               1.0.1
# fa2                      0.3.5
# fancyimpute              0.4.3
# fastai                   1.0.61
# fastdtw                  0.3.4
# fastprogress             0.2.3
# fastrlock                0.4
# fbprophet                0.6
# feather-format           0.4.1
# featuretools             0.4.1
# filelock                 3.0.12
# firebase-admin           4.1.0
# fix-yahoo-finance        0.0.22
# Flask                    1.1.2
# folium                   0.8.3
# fsspec                   0.7.4
# future                   0.16.0
# gast                     0.3.3
# GDAL                     2.2.2
# gdown                    3.6.4
# gensim                   3.6.0
# geographiclib            1.50
# geopy                    1.17.0
# gin-config               0.3.0
# glob2                    0.7
# google                   2.0.3
# google-api-core          1.16.0
# google-api-python-client 1.7.12
# google-auth              1.7.2
# google-auth-httplib2     0.0.3
# google-auth-oauthlib     0.4.1
# google-cloud-bigquery    1.21.0
# google-cloud-core        1.0.3
# google-cloud-datastore   1.8.0
# google-cloud-firestore   1.7.0
# google-cloud-language    1.2.0
# google-cloud-storage     1.18.1
# google-cloud-translate   1.5.0
# google-colab             1.0.0
# google-pasta             0.2.0
# google-resumable-media   0.4.1
# googleapis-common-protos 1.51.0
# googledrivedownloader    0.4
# graphviz                 0.10.1
# grpcio                   1.29.0
# gspread                  3.0.1
# gspread-dataframe        3.0.6
# gym                      0.17.2
# h5py                     2.10.0
# HeapDict                 1.0.1
# holidays                 0.9.12
# html5lib                 1.0.1
# httpimport               0.5.18
# httplib2                 0.17.3
# httplib2shim             0.0.3
# humanize                 0.5.1
# hyperopt                 0.1.2
# ideep4py                 2.0.0.post3
# idna                     2.9
# image                    1.5.31
# imageio                  2.4.1
# imagesize                1.2.0
# imbalanced-learn         0.4.3
# imblearn                 0.0
# imgaug                   0.2.9
# importlib-metadata       1.6.0
# imutils                  0.5.3
# inflect                  2.1.0
# intel-openmp             2020.0.133
# intervaltree             2.1.0
# ipykernel                4.10.1
# ipython                  5.5.0
# ipython-genutils         0.2.0
# ipython-sql              0.3.9
# ipywidgets               7.5.1
# itsdangerous             1.1.0
# jax                      0.1.67
# jaxlib                   0.1.47
# jdcal                    1.4.1
# jedi                     0.17.0
# jieba                    0.42.1
# Jinja2                   2.11.2
# jmespath                 0.10.0
# joblib                   0.15.1
# jpeg4py                  0.1.4
# jsonschema               2.6.0
# jupyter                  1.0.0
# jupyter-client           5.3.4
# jupyter-console          5.2.0
# jupyter-core             4.6.3
# kaggle                   1.5.6
# kapre                    0.1.3.1
# Keras                    2.3.1
# Keras-Applications       1.0.8
# Keras-Preprocessing      1.1.2
# keras-vis                0.4.1
# kiwisolver               1.2.0
# knnimpute                0.1.0
# librosa                  0.6.3
# lightgbm                 2.2.3
# llvmlite                 0.31.0
# lmdb                     0.98
# lucid                    0.3.8
# LunarCalendar            0.0.9
# lxml                     4.2.6
# Markdown                 3.2.2
# MarkupSafe               1.1.1
# matplotlib               3.2.1
# matplotlib-venn          0.11.5
# missingno                0.4.2
# mistune                  0.8.4
# mizani                   0.6.0
# mkl                      2019.0
# mlxtend                  0.14.0
# more-itertools           8.3.0
# moviepy                  0.2.3.5
# mpmath                   1.1.0
# msgpack                  1.0.0
# multiprocess             0.70.9
# multitasking             0.0.9
# murmurhash               1.0.2
# music21                  5.5.0
# natsort                  5.5.0
# nbconvert                5.6.1
# nbformat                 5.0.6
# networkx                 2.4
# nibabel                  3.0.2
# nltk                     3.2.5
# notebook                 5.2.2
# np-utils                 0.5.12.1
# numba                    0.48.0
# numexpr                  2.7.1
# numpy                    1.18.4
# nvidia-ml-py3            7.352.0
# oauth2client             4.1.3
# oauthlib                 3.1.0
# okgrade                  0.4.3
# opencv-contrib-python    4.1.2.30
# opencv-python            4.1.2.30
# openpyxl                 2.5.9
# opt-einsum               3.2.1
# osqp                     0.6.1
# packaging                20.4
# palettable               3.3.0
# pandas                   1.0.3
# pandas-datareader        0.8.1
# pandas-gbq               0.11.0
# pandas-profiling         1.4.1
# pandocfilters            1.4.2
# parso                    0.7.0
# pathlib                  1.0.1
# patsy                    0.5.1
# pexpect                  4.8.0
# pickleshare              0.7.5
# Pillow                   7.0.0
# pip                      19.3.1
# pip-tools                4.5.1
# plac                     1.1.3
# plotly                   4.4.1
# plotnine                 0.6.0
# pluggy                   0.7.1
# portpicker               1.3.1
# prefetch-generator       1.0.1
# preshed                  3.0.2
# prettytable              0.7.2
# progressbar2             3.38.0
# prometheus-client        0.8.0
# promise                  2.3
# prompt-toolkit           1.0.18
# protobuf                 3.10.0
# psutil                   5.4.8
# psycopg2                 2.7.6.1
# ptvsd                    5.0.0a12
# ptyprocess               0.6.0
# py                       1.8.1
# pyarrow                  0.14.1
# pyasn1                   0.4.8
# pyasn1-modules           0.2.8
# pycocotools              2.0.0
# pycparser                2.20
# pydata-google-auth       1.1.0
# pydot                    1.3.0
# pydot-ng                 2.0.0
# pydotplus                2.0.2
# PyDrive                  1.3.1
# pyemd                    0.5.1
# pyglet                   1.5.0
# Pygments                 2.1.3
# pygobject                3.26.1
# pymc3                    3.7
# PyMeeus                  0.3.7
# pymongo                  3.10.1
# pymystem3                0.2.0
# PyOpenGL                 3.1.5
# pyparsing                2.4.7
# pyrsistent               0.16.0
# pysndfile                1.3.8
# PySocks                  1.7.1
# pystan                   2.19.1.1
# pytest                   3.6.4
# python-apt               1.6.5+ubuntu0.2
# python-chess             0.23.11
# python-dateutil          2.8.1
# python-louvain           0.14
# python-slugify           4.0.0
# python-twitter           3.5
# python-utils             2.4.0
# pytz                     2018.9
# PyWavelets               1.1.1
# PyYAML                   3.13
# pyzmq                    19.0.1
# qtconsole                4.7.4
# QtPy                     1.9.0
# regex                    2019.12.20
# requests                 2.23.0
# requests-oauthlib        1.3.0
# resampy                  0.2.2
# retrying                 1.3.3
# rpy2                     3.2.7
# rsa                      4.0
# s3fs                     0.4.2
# s3transfer               0.3.3
# scikit-image             0.16.2
# scikit-learn             0.22.2.post1
# scipy                    1.4.1
# screen-resolution-extra  0.0.0
# scs                      2.1.2
# seaborn                  0.10.1
# Send2Trash               1.5.0
# setuptools               46.4.0
# setuptools-git           1.2
# Shapely                  1.7.0
# simplegeneric            0.8.1
# six                      1.12.0
# sklearn                  0.0
# sklearn-pandas           1.8.0
# smart-open               2.0.0
# snowballstemmer          2.0.0
# sortedcontainers         2.1.0
# spacy                    2.2.4
# Sphinx                   1.8.5
# sphinxcontrib-websupport 1.2.2
# SQLAlchemy               1.3.17
# sqlparse                 0.3.1
# srsly                    1.0.2
# statsmodels              0.10.2
# sympy                    1.1.1
# tables                   3.4.4
# tabulate                 0.8.7
# tbb                      2020.0.133
# tblib                    1.6.0
# tensorboard              2.2.1
# tensorboard-plugin-wit   1.6.0.post3
# tensorboardcolab         0.0.22
# tensorflow               2.2.0
# tensorflow-addons        0.8.3
# tensorflow-datasets      2.1.0
# tensorflow-estimator     2.2.0
# tensorflow-gcs-config    2.1.8
# tensorflow-hub           0.8.0
# tensorflow-metadata      0.22.0
# tensorflow-privacy       0.2.2
# tensorflow-probability   0.10.0
# termcolor                1.1.0
# terminado                0.8.3
# testpath                 0.4.4
# text-unidecode           1.3
# textblob                 0.15.3
# textgenrnn               1.4.1
# Theano                   1.0.4
# thinc                    7.4.0
# tifffile                 2020.5.25
# toolz                    0.10.0
# torch                    1.5.0+cu101
# torchsummary             1.5.1
# torchtext                0.3.1
# torchvision              0.6.0+cu101
# tornado                  4.5.3
# tqdm                     4.41.1
# traitlets                4.3.3
# tweepy                   3.6.0
# typeguard                2.7.1
# typing                   3.6.6
# typing-extensions        3.6.6
# tzlocal                  1.5.1
# umap-learn               0.4.3
# uritemplate              3.0.1
# urllib3                  1.24.3
# vega-datasets            0.8.0
# wasabi                   0.6.0
# wcwidth                  0.1.9
# webencodings             0.5.1
# Werkzeug                 1.0.1
# wheel                    0.34.2
# widgetsnbextension       3.5.1
# wordcloud                1.5.0
# wrapt                    1.12.1
# xarray                   0.15.1
# xgboost                  0.90
# xkit                     0.0.0
# xlrd                     1.1.0
# xlwt                     1.3.0
# yellowbrick              0.9.1
# zict                     2.0.0
# zipp                     3.1.0

# %%
# !apt-get install htop
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   strace
# The following NEW packages will be installed:
#   htop
# 0 upgraded, 1 newly installed, 0 to remove and 31 not upgraded.
# Need to get 80.0 kB of archives.
# After this operation, 221 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 htop amd64 2.1.0-3 [80.0 kB]
# Fetched 80.0 kB in 1s (54.1 kB/s)
# Selecting previously unselected package htop.
# (Reading database ... 144439 files and directories currently installed.)
# Preparing to unpack .../htop_2.1.0-3_amd64.deb ...
# Unpacking htop (2.1.0-3) ...
# Setting up htop (2.1.0-3) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
